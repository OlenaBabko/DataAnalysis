# %%
import matplotlib.pyplot as plt
import numpy as np

import os
current_folder=os.getcwd()
os.chdir(r"C:\Users\Manab\Desktop\dataf")

# %%
for i in [0,1,2,3,4,6]:
    filename='data'+str(i)+'.csv'
    A=np.loadtxt(filename,delimiter=None)
    x=A[:,0]
    y=A[:,1]
    plt.plot(x,y)
