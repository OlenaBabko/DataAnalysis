# %%
import matplotlib.pyplot as plt
import numpy as np
import h5py as h5
filename='data0.h5'
f=h5.File(filename,'r')

# %%
print(list(f))
# Out:
# ['R1x', 'R2x', 'g1x', 'g2x', 'metadata', 'x_array']

# %%
xdata=f['x_array'][:]

# %%
ydata=f['R2x'][:]

# %%
plt.plot(xdata,ydata)
