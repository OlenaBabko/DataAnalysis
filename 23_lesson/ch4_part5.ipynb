# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df=pd.read_csv('data1.csv')

# %%
print(df)
# Out:
#         data_x    data_y
# 0    -3.945937  163.9140
# 1    -3.942344  163.9730
# 2    -3.938750  164.1520
# 3    -3.935156  164.5690
# 4    -3.931563  165.3440
# ...        ...       ...
# 2196  3.945937   60.7374
# 2197  3.949531   60.4989
# 2198  3.953125   60.2009
# 2199  3.956719   59.9625
# 2200  3.960313   59.5453
#
# [2201 rows x 2 columns]

# %%
x=df['data_x']
y=df['data_y']

plt.plot(x,y)
